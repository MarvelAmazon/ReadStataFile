# %% [markdown]
# <a href="https://colab.research.google.com/github/MarvelAmazon/ReadStataFile/blob/main/NLP_job.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Kouman ou ka dekri domenn yon dyòb deskripsyon avèk NLP.
#
# ### 1.Entwodiksyon
#   An Ayiti Chache yon dyòb ki makonnen ak domenn konpetans ou se yon bagay ki difisil anpil.Nou souvan wè yon **Enfimyè** ap travay nan yon **faktori** yon **Engenyè** ap travay tankou yon **planifikatè** yon **Medsen** irije tèt yo an bon **dizwit** an **Administratè** san pou otan se pa domenn konpetans yo vwa aprann konpetans sila yo menm yon fwa nan lavi yo . Yo chita pafwa dèyè yon biwo ap aprann metye y'ap fè a tankou yon bon apranti ,ak yon entèlijans grenn senk pou yo pa bay bon rezilta.
# </br>
# </br>
#
#
#   Souvan yon telman fè travay yo a byen yo merite yon **chapoba**  makònen ak yon kokennchenn felisitasyon. Fòk ou ta frekan anpil pou ta di sa pa metye sa yo te aprann.
#
# Men sa koze yon dezekilib nan domenn konpetans pou yon dyòb e pafwa mete yon gou amè nan dyòl tout pwofesyonèl ki vle egzèse metye ke yo te aprann  paske yo pa gen ase odas pou pwostile pou yon dyòb ki pa nan domenn konpetans yo te ye a.
#
# Pandan mwen fini aprann **#DeepLearning** **#NLP** **#Tensorflow** **#LSTM** **#RNN**  avèk **#coursera** sipòte pa **#AyitiAnalytics** (**#AA**)  mwen ta renmen gade ki similitid ki egziste ant diferan dyòb yo e ki konpetans similè mwen ki makonnen ak (2) ou plizyè kategori dyòb diferan avèk selman mo ke yon redije dyòb deskripsyon an.
#
# Pou nou fè sa nou pral komanse enstale libreri sila yo

# %% [markdown]
# ### Kòmanse pa chache done ou ap bezwen yo

# %%
# Libreri nou sipoze instale pou nou fè travay sa
# !pip install beautifulsoup4 # # libreri ki pèmèt manipile done ki nan fòma HTML
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
import pandas as pd # libreri pou manipilie done
import numpy as np # libreri pou fè kalkil matrisyèl pèfòman
from bs4 import BeautifulSoup # libreri pou manipile done sou fòma HTML
import requests  # Libreri pou ou resevwa yon rekèt HTTP

# %% [markdown]
# Mwen komanse pa defini done ak varyab mwen ap bezwen yo pou mwen ka fè pwojè sila
# * URL : pou mwen ka estoke lyen paj pou mwen fè rekèt la
# * id : kise se nimewo dyòb sou jobpaw

# %%
# Mwen komanse
id = 13037
url = f'https://www.jobpaw.com/pont/professionnels.php?idj={id}'
url
# Out:
# 'https://www.jobpaw.com/pont/professionnels.php?idj=13037'

# %% [markdown]
# Konye a an nou kreye yon fonksyon ki pèmèt nou jwen yon dyòb sou jobpaw byen rapid
# jwen_job_pa_id: pèmèt pou jwenn yon job pa id li

# %%
def jwen_job_pa_id(id =12):

    url = f'https://www.jobpaw.com/pont/professionnels.php?idj={id}'
    response = requests.get(url)
    jobpaw_soup = None
    if response.status_code == 200:
        jobpaw_soup = BeautifulSoup(response.text,'html.parser')


        body = jobpaw_soup.body
        tables = body.find_all('table')
        trs =tables[0].find_all('tr')
        # list_job = []
        my_dict = dict()
        my_dict["id"] = id
        for tr in trs:
        
            tds =  tr.find_all("td")
            if len(tds) <4:
              for index in range(0,len(tds)//2,2):
                  if  len(str(tds[index])) !=0:
                      key = tds[index].text
                      value = tds[index+1].text
                      my_dict[key] =value
              for index in range(len(tds)//2,len(tds)-1,2):
                  if  len(str(tds[index])) !=0:
                      key = tds[index].text
                      value = tds[index+1].text
                      my_dict[key] =value
        trs =tables[2].find_all('tr')
        tds = trs[0].find_all("td")
        my_dict["content"] = tds[0].text.strip()
        # print(my_dict["content"])
    return my_dict

# %%
# jon test
job_test = jwen_job_pa_id()
print(job_test['content'])
# Out:
# Introduction
# Specific Objectives of Consultancy:
# The Extended term consultant is mapped to LCSHD and is a member of the Haiti Country office team.  Working closely with the Human Development Specialist based in Haiti and the Senior Education Specialist based in Washington, the objectives of the ETC’s assignment will be to supervise ongoing projects and support the preparation of Education Sector operations (Multi-donor trust fund and catalytic fund application) as follows:
#
# Fonctions
# Responsibilities:
#
# 1.	Project Supervision:
# a.	Review project documents such as procurement plans and annual operational plans and provide timely feedback to project team;
# b.	Participate in supervision missions;
# c.	Participate in discussions with project team in order to identify bottlenecks and seek out solutions.
#
# 2. Multi-donor Trust Fund:
# a.	Review existing education sector plans;
# b.	Review existing models and related documents for Bank-administered MDTFs;
# c.	Prepare documents to be shared with potential donors;
# d.	Participate in discussions with key internal members of the team;
# e.	Participate in discussions with external actors and partners.
#
# 3. Catalytic Fund application:
# a.	Review existing documentation on the EFA FTI process;
# b.	Participate in discussions with the “Groupe Séctoriel d’Education” on possible project designs;
# c.	Prepare documents related to the conceptual design of the Catalytic Fund application.
#
# 4.	Perform other tasks as needed.
#
# Qualifications réquises
# Qualifications:
# a.	Advanced degree (MA/MBA) in education, economics, management, international relations, or related fields;
# b.	Experience in project management (3+ years) with proven track record is desirable;
# c.	Strong client orientation with commitment to results;
# d.	Evidence of the ability to produce high quality analytical products;
# e.	Excellent command of the French and English languages, both verbal and written;
# f.	Good computer skills particularly in MS Office software (Excel, Word and PowerPoint) as well as internet;
# g.	Good organization skills and ability to prioritize and deliver assignments as required, and the ability to work under pressure, and meet tight deadlines;
# h.	Willingness to assume on a temporary basis ad-hoc functions outside direct area of responsibilities
#
# Autres remarques
# Applications will be treated in strictest confidentiality. Qualified candidates may submit their letter of interest and CV by email to the following address:
# htrecruitment@worldbank.org
# The deadline for all applications is June 30, 2008.  Only applicants selected for interviews will be contacted.
#
# Date limite
# 2008-06-30

# %% [markdown]
# Konye a nou fini defini fonksyon ke nou bezwen an ann ale chache kouman nou kapab ekstrè tout dyòb sa yo sou sit la

# %%
def generate_segment(start=11, stop=13312, step=500):
    low = start
    segments = []
    for high in np.arange(start=start+step, stop=stop, step=step):
        segments.append((low, high))
        low = high
    if segments[-1][1] < stop:
        segments.append((segments[-1][1], stop))

    return segments

# %%
import random 
user_agent_list = [
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',                
]

# %%
generate_segment(start=11,stop=13038,step=5000)
# Out:
# [(11, 5011), (5011, 10011), (10011, 13038)]

# %%
import multiprocessing
import concurrent.futures

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
jobpaw_files_paths = '/content/drive/MyDrive/JobpawData'

# %%
import os
import time
os.mkdir(jobpaw_files_paths)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-19-0a79c03e7bce> in <module>()
#       1 import os
#       2 import time
# ----> 3 os.mkdir(jobpaw_files_paths)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/JobpawData'

# %%
def get_jobpaw_job(start, stop, prod=True):
    my_list = []
    for index in np.arange(start, stop=stop+1):
        my_dict = {}
        if prod:
            try:
                my_dict = jwen_job_pa_id(index)
                my_list.append(my_dict)
                print(f"Page {index} done")
            except:
               print(f"Page {index} failed")

       

    df_data = pd.DataFrame(my_list)
    df_data.to_json(f"{jobpaw_files_paths}/job_{start}_{stop}.json")
    time.sleep(.3)

# %%
get_jobpaw_job(start=11,stop=12)
# Out:
# Page 11 done
# Page 12 done

# %%
segments = generate_segment(start=11, stop=13038, step=200)
processes = []
for segment in segments:
  p1 = multiprocessing.Process(target=get_jobpaw_job, args=[
                                     segment[0], segment[1]+1])
  p1.start()
  processes.append(p1)
  p1.join()
list_df = []
for segment in segments:
  list_df.append(pd.read_json(f"{jobpaw_files_paths}/job_{segment[0]}_{segment[1]+1}.json"))
df_final = pd.concat(list_df, axis=0)
df_final.to_csv("job.csv")
# Out:
# Page 11 done
# Page 12 done
# Page 13 done
# Page 14 done
# Page 15 done
# Page 16 done
# Page 17 done
# Page 18 done
# Page 19 done
# Page 20 done
# Page 21 done
# Page 22 done
# Page 23 done
# Page 24 done
# Page 25 done
# Page 26 done
# Page 27 done
# Page 28 done
# Page 29 done
# Page 30 done
# Page 31 done
# Page 32 done
# Page 33 done
# Page 34 done
# Page 35 done
# Page 36 done
# Page 37 done
# Page 38 done
# Page 39 done
# Page 40 done
# Page 41 done
# Page 42 done
# Page 43 done
# Page 44 done
# Page 45 done
# Page 46 done
# Page 47 done
# Page 48 done
# Page 49 done
# Page 50 done
# Page 51 done
# Page 52 done
# Page 53 done
# Page 54 done
# Page 55 done
# Page 56 done
# Page 57 done
# Page 58 done
# Page 59 done
# Page 60 done
# Page 61 done
# Page 62 done
# Page 63 done
# Page 64 done
# Page 65 done
# Page 66 done
# Page 67 done
# Page 68 done
# Page 69 done
# Page 70 done
# Page 71 done
# Page 72 done
# Page 73 done
# Page 74 done
# Page 75 done
# Page 76 done
# Page 77 done
# Page 78 done
# Page 79 done
# Page 80 done
# Page 81 done
# Page 82 done
# Page 83 done
# Page 84 done
# Page 85 done
# Page 86 done
# Page 87 done
# Page 88 done
# Page 89 done
# Page 90 done
# Page 91 done
# Page 92 done
# Page 93 done
# Page 94 done
# Page 95 done
# Page 96 done
# Page 97 done
# Page 98 done
# Page 99 done
# Page 100 done
# Page 101 done
# Page 102 done
# Page 103 done
# Page 104 done
# Page 105 done
# Page 106 done
# Page 107 done
# Page 108 done
# Page 109 done
# Page 110 done
# Page 111 done
# Page 112 done
# Page 113 done
# Page 114 done
# Page 115 done
# Page 116 done
# Page 117 done
# Page 118 done
# Page 119 done
# Page 120 done
# Page 121 done
# Page 122 done
# Page 123 done
# Page 124 done
